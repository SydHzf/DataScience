# %%
import numpy as np
import pandas as pd
import openpyxl

# %%
wb = openpyxl.load_workbook("Soccer Salaries.xlsx")
res = wb.sheetnames
print(res)
# Out:
# ['EPL', 'Bundesliga', 'Serie A', 'La Liga', 'Ligue 1', 'MLS', 'NFL', 'NBA', 'MLB', 'NHL', 'WNBA']

# %%
dataset = {}

for i in res:
    dataset[i] = pd.read_excel("Soccer Salaries.xlsx",sheet_name = i)

# %%
dataset.keys()
# Out:
# dict_keys(['EPL', 'Bundesliga', 'Serie A', 'La Liga', 'Ligue 1', 'MLS', 'NFL', 'NBA', 'MLB', 'NHL', 'WNBA'])

# %%
liga_19 = dataset['La Liga'].sort_values(by="2019-20 Salary", ascending = False)
liga_19.shape
# Out:
# (476, 15)

# %%
boolean_mask = liga_19["2019-20 Salary"] != 0

# %%
liga_19 = liga_19.loc[boolean_mask]
liga_19.shape
# Out:
# (348, 15)

# %%
# liga_19[liga_19["2019-20 Salary"] != np.nan]

# %%
liga_19 = liga_19.dropna()

# %%
liga_19.head()
# Out:
#    Rank                                             Player  Weekly Salary  \
# 0     1  Lionel Messi (http://www.capology.com/soccer/p...      1538905.0
# 1     2  Antoine Griezmann (http://www.capology.com/soc...       997032.0
# 2     3  Gareth Bale (http://www.capology.com/soccer/pl...       607706.0
# 3     4  Luis Suárez (http://www.capology.com/soccer/pl...       508923.0
# 4     5  Philippe Coutinho (http://www.capology.com/soc...       508923.0
#
#   Pos.  Age   Status  Length (Yrs)  2018-19 Salary  2019-20 Salary  \
# 0   RW   31  Starter             3      80023053.0      80023053.0
# 1   CF   28  Starter             5      51845682.0      51845682.0
# 2   RW   29  Starter             4      31600725.0      31600725.0
# 3   CF   32  Starter             3      26463996.0      26463996.0
# 4   AM   26  Reserve             5      26463996.0      26463996.0
#
#    2020-21 Salary  2021-22 Salary  2022-23 Salary  2023-24 Salary  \
# 0        80023053               0               0               0
# 1        51845682        51845682        51845682               0
# 2        31600725        31600725               0               0
# 3        26463996               0               0               0
# 4        26463996        26463996        26463996               0
#
#    2024-25 Salary             Club
# 0               0        Barcelona
# 1               0  Atlético Madrid
# 2               0      Real Madrid
# 3               0        Barcelona
# 4               0        Barcelona

# %%
liga_19["Age"].value_counts().sort_index().plot.bar()

# %%
liga_19["Age"].plot.hist(bins = 10, xticks = range(18,38,1), grid =True,figsize=(8,4))

# %%
(liga_19["Age"].max() - liga_19["Age"].min())/10
# Out:
# 1.9

# %%
liga_19["Age"].value_counts(bins=10).sort_index()
# Out:
# (14.999, 20.0]     15
# (20.0, 25.0]      120
# (25.0, 30.0]      156
# (30.0, 35.0]       54
# (35.0, 40.0]        2
# Name: Age, dtype: int64

# %%
age_interval = pd.interval_range(start=15,end=40,freq=5,closed='right')
age_interval
# Out:
# IntervalIndex([(15, 20], (20, 25], (25, 30], (30, 35], (35, 40]],
#               closed='right',
#               dtype='interval[int64]')

# %%
age_interval_frq = pd.Series(index=age_interval,data=0)
age_interval_frq
# Out:
# (15, 20]    0
# (20, 25]    0
# (25, 30]    0
# (30, 35]    0
# (35, 40]    0
# dtype: int64

# %%
for i in liga_19["Age"]: # 31
    for j in age_interval: # (30, 35] 
        if i in j:
            age_interval_frq.loc[j] += 1

# %%
age_interval_frq
# Out:
# (15, 20]     15
# (20, 25]    120
# (25, 30]    156
# (30, 35]     54
# (35, 40]      2
# dtype: int64

# %%
i = 36
for j in age_interval: # (30, 35] 
    if i in j:
        print(j)
# Out:
# (35, 40]

# %%
bins_list = list(range(15,41,5))
print(bins_list)
# Out:
# [15, 20, 25, 30, 35, 40]

# %%
liga_19["Age"].plot.hist(bins=bins_list)

# %%
liga_19["Age"].value_counts(bins=bins_list).sort_index()
# Out:
# (14.999, 20.0]     15
# (20.0, 25.0]      120
# (25.0, 30.0]      156
# (30.0, 35.0]       54
# (35.0, 40.0]        2
# Name: Age, dtype: int64

# %%
top_salaries = liga_19.head(50)
top_salaries
# Out:
#     Rank                                             Player  Weekly Salary  \
# 0      1  Lionel Messi (http://www.capology.com/soccer/p...      1538905.0
# 1      2  Antoine Griezmann (http://www.capology.com/soc...       997032.0
# 2      3  Gareth Bale (http://www.capology.com/soccer/pl...       607706.0
# 3      4  Luis Suárez (http://www.capology.com/soccer/pl...       508923.0
# 4      5  Philippe Coutinho (http://www.capology.com/soc...       508923.0
# 5      6  Marcelo (http://www.capology.com/soccer/player...       434977.0
# 6      7  Sergio Ramos (http://www.capology.com/soccer/p...       434977.0
# 7      8  Toni Kroos (http://www.capology.com/soccer/pla...       434977.0
# 8      9  Luka Modric (http://www.capology.com/soccer/pl...       405311.0
# 9     10  Karim Benzema (http://www.capology.com/soccer/...       359813.0
# 10    11  Diego Costa (http://www.capology.com/soccer/pl...       347764.0
# 11    12  Koke (http://www.capology.com/soccer/player/ko...       346785.0
# 13    14  Sergio Busquets (http://www.capology.com/socce...       325124.0
# 14    15  Ivan Rakitic (http://www.capology.com/soccer/p...       290434.0
# 15    16  Thibaut Courtois (http://www.capology.com/socc...       281778.0
# 16    17  Gerard Piqué (http://www.capology.com/soccer/p...       277080.0
# 17    18  Isco (http://www.capology.com/soccer/player/is...       276145.0
# 19    20  Samuel Umtiti (http://www.capology.com/soccer/...       260986.0
# 18    19  Ousmane Dembélé (http://www.capology.com/socce...       260986.0
# 20    21  Saúl Ñíguez (http://www.capology.com/soccer/pl...       260769.0
# 21    22  Jan Oblak (http://www.capology.com/soccer/play...       234083.0
# 22    23  Vitolo (http://www.capology.com/soccer/player/...       234083.0
# 23    24  Raphaël Varane (http://www.capology.com/soccer...       225427.0
# 24    25  Sergi Roberto (http://www.capology.com/soccer/...       216749.0
# 25    26  Álvaro Morata (http://www.capology.com/soccer/...       214161.0
# 27    28  Arturo Vidal (http://www.capology.com/soccer/p...       195740.0
# 28    29  Iñigo Martínez (http://www.capology.com/soccer...       195065.0
# 25   CF   26  Reserve             2      11136366.0      11136366.0
# 27   CM   31  Reserve             3      10178460.0      10178460.0
# 28   CB   27  Starter             5      10143401.0      10143401.0
# 29   LB   30  Starter             6       9703465.0       9703465.0
# 30   GK   32  Reserve             2       9703465.0       9703465.0
# 31   GK   26  Starter             4       9703465.0       9703465.0
# 32   CF   25  Reserve             5       9703465.0       9703465.0
# 33   LW   23  Starter             5       9424123.0       9424123.0
# 34   CB   30  Starter             3       9424123.0       9424123.0
# 35   RB   27  Starter             4       9355136.0       9355136.0
# 38   CF   31  Reserve             3       8497883.0       8497883.0
# 40   CF   28  Starter             4       7709618.0       7709618.0
# 39   DM   22  Starter             5       7709618.0       7709618.0
# 41   LW   32  Reserve             2       7464204.0       7464204.0
# 42   CM   26  Starter             4       7329622.0       7329622.0
# 45   CF   31  Reserve             3       7322837.0       7322837.0
# 46   LW   23  Starter             5       7322837.0       7322837.0
# 47   CM   30  Starter             2       7283254.0       7283254.0
# 48   CF   32  Starter             4       6920222.0       6920222.0
# 49   AM   32  Starter             2       6527786.0       6527786.0
# 51   LW   22  Reserve             5       6480286.0       6480286.0
# 52   LW   18  Reserve             7       6005291.0       6005291.0
# 53   CM   29  Reserve             4       5973625.0       5973625.0
# 54   CB   32  Reserve             2       5654700.0       5654700.0
# 55   CF   23  Reserve             5       5635474.0       5635474.0
# 56   CM   22  Starter             6       5522380.0       5522380.0
#
#     2020-21 Salary  2021-22 Salary  2022-23 Salary  2023-24 Salary  \
# 0         80023053               0               0               0
# 1         51845682        51845682        51845682               0
# 2         31600725        31600725               0               0
# 3         26463996               0               0               0
# 4         26463996        26463996        26463996               0
# 5         22618800        22618800               0               0
# 6                0               0               0               0
# 7         22618800        22618800               0               0
# 8                0               0               0               0
# 9         18710271               0               0               0
# 10        18083731               0               0               0
# 11        18032838        18032838        18032838        18032838
# 13        16906422        16906422        16906422               0
# 14        15102573               0               0               0
# 15        14652459        14652459        14652459        14652459
# 16        14408176        14408176               0               0
# 17        14359545        14359545               0               0
# 19        13571280        13571280        13571280               0
# 18        13571280        13571280               0               0
# 20        13559971        13559971        13559971        13559971
# 21        12172307               0               0               0
# 22        12172307        12172307               0               0
# 23        11722193        11722193               0               0
# 24        11270948        11270948               0               0
# 25               0               0               0               0
# 27        10178460               0               0               0
# 28        10143401        10143401        10143401               0
# 29         9703465         9703465         9703465         9703465
# 30               0               0               0               0
# 31         9703465         9703465               0               0
# 32         9703465         9703465         9703465               0
# 33         9424123         9424123         9424123               0
# 34         9424123               0               0               0
# 35         9355136         9355136               0               0
# 38         8497883               0               0               0
# 40         7709618         7709618               0               0
# 39         7709618         7709618         7709618               0
# 41               0               0               0               0
# 42         7329622         7329622               0               0
# 45         7322837               0               0               0
# 46         7322837         7322837         7322837               0
# 47               0               0               0               0
# 48         6920222         6920222               0               0
# 49               0               0               0               0
# 51         6480286         6480286         6480286               0
# 52         6005291         6005291         6005291         6005291
# 53         5973625         5973625               0               0
# 54               0               0               0               0
# 55         5635474         5635474         5635474               0
# 56         5522380         5522380         5522380         5522380
#
#     2024-25 Salary             Club
# 0                0        Barcelona
# 1                0  Atlético Madrid
# 2                0      Real Madrid
# 3                0        Barcelona
# 4                0        Barcelona
# 5                0      Real Madrid
# 6                0      Real Madrid
# 7                0      Real Madrid
# 8                0      Real Madrid
# 9                0      Real Madrid
# 10               0  Atlético Madrid
# 11               0  Atlético Madrid
# 13               0        Barcelona
# 14               0        Barcelona
# 15               0      Real Madrid
# 16               0        Barcelona
# 17               0      Real Madrid
# 19               0        Barcelona
# 18               0        Barcelona
# 20        13559971  Atlético Madrid
# 21               0  Atlético Madrid
# 22               0  Atlético Madrid
# 23               0      Real Madrid
# 24               0        Barcelona
# 25               0  Atlético Madrid
# 27               0        Barcelona
# 28               0    Athletic Club
# 29               0        Barcelona
# 30               0      Real Madrid
# 31               0        Barcelona
# 32               0      Real Madrid
# 33               0      Real Madrid
# 34               0          Sevilla
# 35               0      Real Madrid
# 38               0         Valencia
# 40               0         Valencia
# 39               0  Atlético Madrid
# 41               0          Sevilla
# 42               0         Valencia
# 45               0  Atlético Madrid
# 46               0  Atlético Madrid
# 47               0          Sevilla
# 48               0       Villarreal
# 49               0    Athletic Club
# 51               0         Valencia
# 52         6005291      Real Madrid
# 53               0         Valencia
# 54               0         Valencia
# 55               0          Sevilla
# 56               0        Barcelona

# %%
top_salaries["Club"].value_counts()
# Out:
# Real Madrid        14
# Barcelona          13
# Atlético Madrid    10
# Valencia            6
# Sevilla             4
# Athletic Club       2
# Villarreal          1
# Name: Club, dtype: int64

# %%
top_salaries["Club"].value_counts().plot.bar()

# %%
# unique = top_salaries["Club"].unique()
# unique
# Out:
# array(['Barcelona', 'Atlético Madrid', 'Real Madrid', 'Athletic Club',
#        'Sevilla', 'Valencia', 'Villarreal'], dtype=object)

# %%
unique = top_salaries["Club"].value_counts().index
unique
# Out:
# Index(['Real Madrid', 'Barcelona', 'Atlético Madrid', 'Valencia', 'Sevilla',
#        'Athletic Club', 'Villarreal'],
#       dtype='object')

# %%
club_sum = {}

for i in unique:
    club_sum[i] = round(top_salaries.loc[top_salaries["Club"] == i,"2019-20 Salary"].sum())

# %%
club_sum
# Out:
# {'Real Madrid': 224169271,
#  'Barcelona': 252889494,
#  'Atlético Madrid': 159358494,
#  'Valencia': 41645734,
#  'Sevilla': 29807055,
#  'Athletic Club': 16671187,
#  'Villarreal': 6920222}

# %%
ax = top_salaries["Club"].value_counts().plot.bar(yticks = range(0,18,2))

loc = 0
for i in club_sum.values():
    ax.annotate(s=i,xy=(-.05+loc,6),rotation=90)
    loc += 1

# %%
ax.patches[1].get_height()
# Out:
# 13

# %%
print(res[0:5])
# Out:
# ['EPL', 'Bundesliga', 'Serie A', 'La Liga', 'Ligue 1']

# %%
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())
totals
# Out:
# [14, 13, 10, 6, 4, 2, 1]
