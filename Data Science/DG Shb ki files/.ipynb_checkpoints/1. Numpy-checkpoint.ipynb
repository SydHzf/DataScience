# %%
lst = [2,4,6,8]
len(lst)
# Out:
# 4

# %%
for i in range(4):
    lst[i] = lst[i] ** 2
lst
# Out:
# [4, 16, 36, 64]

# %% [markdown]
# ### Numpy Data Structure is ndarray

# %%
import numpy as np

# %%
lst = [2,4,6,8]

# %%
type(lst)
# Out:
# list

# %%
array = np.array([2,4,6,8])
array
# Out:
# array([2, 4, 6, 8])

# %%
type(array)
# Out:
# numpy.ndarray

# %% [markdown]
# ### SIMD : Single Instruction Multiple Data

# %%
array = array ** 2
array
# Out:
# array([ 4, 16, 36, 64], dtype=int32)

# %%
array.dtype
# Out:
# dtype('int32')

# %%
array.ndim
# Out:
# 1

# %%
array
# Out:
# array([ 4, 16, 36, 64], dtype=int32)

# %%
array[-2]
# Out:
# 36

# %%
lst = [[1,2,3],[4,5,6],[6,5,4]]
lst
# Out:
# [[1, 2, 3], [4, 5, 6], [6, 5, 4]]

# %%
array = np.array(lst)
array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [6, 5, 4]])

# %%
array[-1][0]
# Out:
# 6

# %%
array[1][-1]
# Out:
# 6

# %%
array.ndim
# Out:
# 2

# %%
array.sum()
# Out:
# 36

# %% [markdown]
# # Axis
#     * axis = 0 (row-wise operation)
#     * axis = 1 (col-wise operation)

# %%
array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [6, 5, 4]])

# %%
array.sum(axis = 0)
# Out:
# array([11, 12, 13])

# %%
array.sum(axis = 1)
# Out:
# array([ 6, 15, 15])

# %%
dataset = np.genfromtxt("nyc_taxis.csv", delimiter = ",", skip_header = 1, dtype = float)
dataset
# Out:
# array([[2.016e+03, 1.000e+00, 1.000e+00, ..., 1.165e+01, 6.999e+01,
#         1.000e+00],
#        [2.016e+03, 1.000e+00, 1.000e+00, ..., 8.000e+00, 5.430e+01,
#         1.000e+00],
#        [2.016e+03, 1.000e+00, 1.000e+00, ..., 0.000e+00, 3.780e+01,
#         2.000e+00],
#        ...,
#        [2.016e+03, 6.000e+00, 3.000e+01, ..., 5.000e+00, 6.334e+01,
#         1.000e+00],
#        [2.016e+03, 6.000e+00, 3.000e+01, ..., 8.950e+00, 4.475e+01,
#         1.000e+00],
#        [2.016e+03, 6.000e+00, 3.000e+01, ..., 0.000e+00, 5.484e+01,
#         2.000e+00]])

# %%
dataset.dtype
# Out:
# dtype('float64')

# %%
dataset.ndim
# Out:
# 2

# %%
dataset[2]
# Out:
# array([2.016e+03, 1.000e+00, 1.000e+00, 5.000e+00, 0.000e+00, 2.000e+00,
#        6.000e+00, 1.270e+01, 1.462e+03, 3.650e+01, 1.300e+00, 0.000e+00,
#        0.000e+00, 3.780e+01, 2.000e+00])

# %%
dataset[15:26]
# Out:
# array([[2.016e+03, 1.000e+00, 1.000e+00, 5.000e+00, 1.000e+00, 4.000e+00,
#         3.000e+00, 1.209e+01, 1.265e+03, 3.350e+01, 1.300e+00, 5.540e+00,
#         1.008e+01, 5.042e+01, 1.000e+00],
#        [2.016e+03, 1.000e+00, 1.000e+00, 5.000e+00, 1.000e+00, 2.000e+00,
#         4.000e+00, 1.730e+01, 1.588e+03, 5.200e+01, 8.000e-01, 5.540e+00,
#         0.000e+00, 5.834e+01, 2.000e+00],
#        [2.016e+03, 1.000e+00, 1.000e+00, 5.000e+00, 1.000e+00, 2.000e+00,
#         1.000e+00, 1.374e+01, 2.304e+03, 4.200e+01, 1.300e+00, 0.000e+00,
#         5.000e+00, 4.830e+01, 1.000e+00],
#        [2.016e+03, 1.000e+00, 1.000e+00, 5.000e+00, 1.000e+00, 4.000e+00,
#         2.000e+00, 1.757e+01, 1.654e+03, 5.200e+01, 8.000e-01, 5.540e+00,
#         0.000e+00, 5.834e+01, 2.000e+00],
#        [2.016e+03, 1.000e+00, 1.000e+00, 5.000e+00, 1.000e+00, 4.000e+00,
#         3.000e+00, 9.500e+00, 1.299e+03, 2.850e+01, 1.300e+00, 0.000e+00,
#         5.960e+00, 3.576e+01, 1.000e+00],
# ...

# %%
dataset[:11,9:13] # [row,col]
# Out:
# array([[ 52.  ,   0.8 ,   5.54,  11.65],
#        [ 45.  ,   1.3 ,   0.  ,   8.  ],
#        [ 36.5 ,   1.3 ,   0.  ,   0.  ],
#        [ 26.  ,   1.3 ,   0.  ,   5.46],
#        [ 17.5 ,   1.3 ,   0.  ,   0.  ],
#        [ 52.  ,   0.8 ,   0.  ,  52.8 ],
#        [ 24.5 ,   1.3 ,   0.  ,   6.45],
#        [ 21.5 ,   1.3 ,   0.  ,   0.  ],
#        [109.5 ,   0.8 ,  11.08,  10.  ],
#        [ 36.  ,   1.3 ,   0.  ,   0.  ],
#        [ 52.  ,   0.8 ,   5.54,   0.  ]])

# %%
len(dataset)
# Out:
# 89560

# %%
array[1,1]
# Out:
# 5

# %%
cal_amount = dataset[:,9:13].sum(axis = 1)
cal_amount
# Out:
# array([69.99, 54.3 , 37.8 , ..., 63.34, 44.75, 54.84])

# %%
actual_amount = dataset[:,13]
actual_amount
# Out:
# array([69.99, 54.3 , 37.8 , ..., 63.34, 44.75, 54.84])

# %%
for i in range(len(cal_amount)):
    print(cal_amount[i] == actual_amount[i])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# False
# False
# True
# False
# False
# True
# False
# True
# True
# True
# False
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# False
# True
# False
# False
# True
# False
# False
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# False
# True
# True
# True
# True
# True
# True
# False
# True
# True
# False
# True
# True
# True
# False
# False
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# True
# False
# True
# True
# True
# False
# False
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# False
# True
# True
# False
# False
# True
# True
# True
# True
# True
# False
# True
# False
# True
# True
# True
# True
# True
# False
# True
# True
# False
# ...

# %%
lst = [1,2,3]
lst1 = [1,3,3]
lst == lst1
# Out:
# False

# %%
boolean = actual_amount == cal_amount
len(boolean)
# Out:
# 89560

# %%
dataset[boolean]
# Out:
# array([[2.016e+03, 1.000e+00, 1.000e+00, ..., 1.165e+01, 6.999e+01,
#         1.000e+00],
#        [2.016e+03, 1.000e+00, 1.000e+00, ..., 8.000e+00, 5.430e+01,
#         1.000e+00],
#        [2.016e+03, 1.000e+00, 1.000e+00, ..., 0.000e+00, 3.780e+01,
#         2.000e+00],
#        ...,
#        [2.016e+03, 6.000e+00, 3.000e+01, ..., 3.500e+00, 2.680e+01,
#         1.000e+00],
#        [2.016e+03, 6.000e+00, 3.000e+01, ..., 2.000e+00, 1.480e+01,
#         1.000e+00],
#        [2.016e+03, 6.000e+00, 3.000e+01, ..., 8.950e+00, 4.475e+01,
#         1.000e+00]])

# %%
89560-57151
# Out:
# 32409

# %%
dataset[boolean == False,13]
# Out:
# array([58.34, 70.01, 58.34, ..., 58.34, 63.34, 54.84])

# %%
dataset[:,13] = cal_amount

# %%
np.where(boolean == False)
# Out:
# (array([   10,    12,    13, ..., 89556, 89557, 89559], dtype=int64),)

# %%
array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [6, 5, 4]])

# %%
bl = np.array([True,False,True])
bl
# Out:
# array([ True, False,  True])

# %%
array[bl == True]
# Out:
# array([[1, 2, 3],
#        [6, 5, 4]])

# %%
len(bl)
# Out:
# 3

# %%
len(array)
# Out:
# 3
