# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
db = "jobs.db"
conn = sql.connect(db)

# %%
def q(q):
    return pd.read_sql_query(q,conn)

# %%
q("""select Major,ShareWomen,Major_category from recent_grads 
    where ShareWomen <= (ShareWomen) """)
# Out:
#                                          Major  ShareWomen  \
# 0                        PETROLEUM ENGINEERING    0.120564
# 1               MINING AND MINERAL ENGINEERING    0.101852
# 2                    METALLURGICAL ENGINEERING    0.153037
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING    0.107313
# 4                         CHEMICAL ENGINEERING    0.341631
# ..                                         ...         ...
# 168                                    ZOOLOGY    0.637293
# 169                     EDUCATIONAL PSYCHOLOGY    0.817099
# 170                        CLINICAL PSYCHOLOGY    0.799859
# 171                      COUNSELING PSYCHOLOGY    0.798746
# 172                            LIBRARY SCIENCE    0.877960
#
#                Major_category
# 0                 Engineering
# 1                 Engineering
# 2                 Engineering
# 3                 Engineering
# 4                 Engineering
# ..                        ...
# 168    Biology & Life Science
# ...

# %%
q("""select Major,ShareWomen,Major_category from recent_grads
    where ShareWomen >= avg(ShareWomen) """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: misuse of aggregate function avg()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-9-b3e5c85d2325> in <module>
# ----> 1 q("""select Major,ShareWomen,Major_category from recent_grads
#       2     where ShareWomen >= avg(ShareWomen) """)
#
# <ipython-input-3-5bf7af33ec18> in q(q)
#       1 def q(q):
# ----> 2     return pd.read_sql_query(q,conn)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     375     """
# ...

# %%
q("""select Major,ShareWomen,Major_category 
   from recent_grads where ShareWomen > (select avg(ShareWomen) from recent_grads) 
   order by ShareWomen""")
# Out:
#                                Major  ShareWomen  \
# 0                       PHARMACOLOGY    0.524153
# 1               INFORMATION SCIENCES    0.526476
# 2                             BOTANY    0.528969
# 3                          SOCIOLOGY    0.532334
# 4                  ACTUARIAL SCIENCE    0.535714
# ..                               ...         ...
# 86                   ANIMAL SCIENCES    0.910933
# 87              ELEMENTARY EDUCATION    0.923745
# 88  MATHEMATICS AND COMPUTER SCIENCE    0.927807
# 89         EARLY CHILDHOOD EDUCATION    0.967998
# 90       ANTHROPOLOGY AND ARCHEOLOGY    0.968954
#
#                      Major_category
# 0            Biology & Life Science
# 1           Computers & Mathematics
# 2            Biology & Life Science
# 3                    Social Science
# 4                          Business
# ..                              ...
# 86  Agriculture & Natural Resources
# 87                        Education
# 88          Computers & Mathematics
# ...

# %%
q("""select Count(ShareWomen) as Avg_count, (select count(*) from recent_grads)  'Total'
from recent_grads 
where ShareWomen > (select avg(ShareWomen) 
from recent_grads )""")
# Out:
#    Avg_count  Total
# 0         91    173

# %%
q("""select Major_category,sum(shareWomen)/(select count(*) from recent_grads)  "Avg"
from recent_grads 
where ShareWomen > (select avg(ShareWomen) 
from recent_grads )
group by 
Major_category
""")
# Out:
#                          Major_category       Avg
# 0       Agriculture & Natural Resources  0.031452
# 1                                  Arts  0.018877
# 2                Biology & Life Science  0.041129
# 3                              Business  0.014583
# 4           Communications & Journalism  0.013123
# 5               Computers & Mathematics  0.025197
# 6                             Education  0.052341
# 7                           Engineering  0.007567
# 8                                Health  0.036633
# 9             Humanities & Liberal Arts  0.051324
# 10  Industrial Arts & Consumer Services  0.008301
# 11                  Law & Public Policy  0.003416
# 12                    Physical Sciences  0.012950
# 13             Psychology & Social Work  0.037940
# 14                       Social Science  0.017623

# %%
q("""select (cast(count(*) as float)/(select count(*) from recent_grads))*100 as Percentage   
from recent_grads 
where ShareWomen > (select avg(ShareWomen) 
from recent_grads )""")
# Out:
#    Percentage
# 0   52.601156

# %%
q("""select major,major_category
from recent_grads 
where  major_category in ("Engineering","Business")""")
# Out:
#                                               Major Major_category
# 0                             PETROLEUM ENGINEERING    Engineering
# 1                    MINING AND MINERAL ENGINEERING    Engineering
# 2                         METALLURGICAL ENGINEERING    Engineering
# 3         NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4                              CHEMICAL ENGINEERING    Engineering
# 5                               NUCLEAR ENGINEERING    Engineering
# 6                                 ACTUARIAL SCIENCE       Business
# 7                            MECHANICAL ENGINEERING    Engineering
# 8                            ELECTRICAL ENGINEERING    Engineering
# 9                              COMPUTER ENGINEERING    Engineering
# 10                            AEROSPACE ENGINEERING    Engineering
# 11                           BIOMEDICAL ENGINEERING    Engineering
# 12                                MATERIALS SCIENCE    Engineering
# ...

# %%
q("select * from recent_grads;")
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
q("""select Major_category,sum(Total) as Student from recent_grads 
group by 1
order by 2 desc
""")
# Out:
#                          Major_category  Student
# 0                              Business  1302376
# 1             Humanities & Liberal Arts   713468
# 2                             Education   559129
# 3                           Engineering   537583
# 4                        Social Science   529966
# 5              Psychology & Social Work   481007
# 6                                Health   463230
# 7                Biology & Life Science   453862
# 8           Communications & Journalism   392601
# 9                                  Arts   357130
# 10              Computers & Mathematics   299008
# 11  Industrial Arts & Consumer Services   229792
# 12                    Physical Sciences   185479
# 13                  Law & Public Policy   179107
# 14      Agriculture & Natural Resources    79981
# 15                    Interdisciplinary    12296

# %%
db = "factbook.db"
conn = sql.connect(db)
q("select * from sqlite_master")
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table  sqlite_sequence  sqlite_sequence         3
# 1  table            facts            facts        47
# 2  table           cities           cities         2
# 3  table             user             user         5
# 4  table    purchase_info    purchase_info         6
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY...
# 2  CREATE TABLE cities (\n        id integer prim...
# 3  CREATE TABLE user(\nid Integer primary key,\nf...
# 4  CREATE TABLE purchase_info(\npurchase_id Integ...

# %% [markdown]
# <image src="table model.JPG"  />

# %%
q("select * from cities where facts_id == '132'")
# Out:
#     id        name  population  capital facts_id
# 0  273     Karachi    13876000        0      132
# 1  274      Lahore     7566000        0      132
# 2  275  Faisalabad     3038000        0      132
# 3  276  Rawalpindi     2164000        0      132
# 4  277      Multan     1775000        0      132
# 5  278   Islamabad      919000        1      132

# %% [markdown]
# # Joining

# %%
q("""select f.name Country_name,
c.name Country_name,
c.population City_population,
f.population Country_population,
c.capital Capital
from facts as f
inner join cities as c
on
c.facts_id = f.id
""")
# Out:
#              Country_name  Country_name  City_population  Country_population  \
# 0                   Aruba    Oranjestad            37000              112162
# 1     Antigua and Barbuda  Saint John'S            27000               92436
# 2    United Arab Emirates     Abu Dhabi           942000             5779760
# 3    United Arab Emirates         Dubai          1978000             5779760
# 4    United Arab Emirates       Sharjah           983000             5779760
# ..                    ...           ...              ...                 ...
# 392             Swaziland       Mbabane            66000             1435613
# 393                 Yemen         Sanaa          2419000            26737317
# 394                 Yemen          Aden           784000            26737317
# 395                Zambia        Lusaka          1802000            15066266
# 396              Zimbabwe        Harare          1542000            14229541
#
#      Capital
# 0          1
# 1          1
# ...

# %%
q("""select f.name Country_name,
c.name Country_name,
c.population City_population,
f.population Country_population,
c.capital Capital
from facts as f
left join cities as c
on
c.facts_id = f.id
""")

# %%
q("""select f.name Country_name,
c.name City_name,
c.population City_population,
f.population Country_population,
c.capital Capital
from facts as f
left join cities as c
on
c.facts_id = f.id
where City_name is Null
""")
# Out:
#                                      Country_name City_name City_population  \
# 0                                          Kosovo      None            None
# 1                                          Monaco      None            None
# 2                                           Nauru      None            None
# 3                                      San Marino      None            None
# 4                                       Singapore      None            None
# 5                         Holy See (Vatican City)      None            None
# 6                                          Taiwan      None            None
# 7                                  European Union      None            None
# 8                     Ashmore and Cartier Islands      None            None
# 9                                Christmas Island      None            None
# 10                        Cocos (Keeling) Islands      None            None
# ...
