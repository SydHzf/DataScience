# %%
# !pip install PyPDF2

# %%
import PyPDF2 as ydf

# %%
print("huzaifa", end = ' '),print("ali")
# Out:
# huzaifa ali
# (None, None)

# %%
file = open("Enthought-Python-Pandas-Cheat-Sheets-1-8-v1-Copy1.0.2.pdf","rb")

# %%
file
# Out:
# <_io.BufferedReader name='Enthought-Python-Pandas-Cheat-Sheets-1-8-v1-Copy1.0.2.pdf'>

# %%
reader = ydf.PdfFileReader(file)

# %%
print(reader.numPages)
# Out:
# 8

# %%
reader.getPage(0)
# Out:
# {'/ArtBox': [3.61049, 9.31755, 604.8, 786.562],
#  '/BleedBox': [0, 0, 612, 792],
#  '/Contents': [IndirectObject(711, 0),
#   IndirectObject(712, 0),
#   IndirectObject(713, 0),
#   IndirectObject(714, 0),
#   IndirectObject(715, 0),
#   IndirectObject(716, 0),
#   IndirectObject(717, 0),
#   IndirectObject(718, 0)],
#  '/CropBox': [0, 0, 612, 792],
#  '/MediaBox': [0, 0, 612, 792],
#  '/Parent': {'/Count': 8,
#   '/Kids': [IndirectObject(709, 0),
#    IndirectObject(1, 0),
#    IndirectObject(103, 0),
#    IndirectObject(105, 0),
#    IndirectObject(134, 0),
#    IndirectObject(157, 0),
#    IndirectObject(206, 0),
#    IndirectObject(237, 0)],
#   '/Type': '/Pages'},
#  '/Resources': {'/ColorSpace': {'/CS0': ['/ICCBased', IndirectObject(719, 0)],
#    '/CS1': ['/Indexed', IndirectObject(854, 0), 1, IndirectObject(720, 0)],
#    '/CS10': ['/Indexed', IndirectObject(854, 0), 182, IndirectObject(721, 0)],
#    '/CS11': ['/Indexed', IndirectObject(854, 0), 8, IndirectObject(722, 0)],
# ...
