# %%
import pandas as pd
pd.options.display.max_rows = 1000

# %%
f500 = pd.read_csv("datasets/f500.csv")

# %%
f500
# Out:
#                                           company  rank  revenues  \
# 0                                         Walmart     1    485873
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 4                                    Toyota Motor     5    254694
# 5                                      Volkswagen     6    240264
# 6                               Royal Dutch Shell     7    240033
# 7                              Berkshire Hathaway     8    223604
# 8                                           Apple     9    215639
# 9                                     Exxon Mobil    10    205004
# 10                                       McKesson    11    198533
# 11                                             BP    12    186606
# 12                             UnitedHealth Group    13    184840
# ...

# %%
500*17
# Out:
# 8500

# %%
f500.dtypes
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
f500.shape
# Out:
# (500, 17)

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
print(type(f500))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
f500.describe()
# Out:
#              rank       revenues  revenue_change       profits        assets  \
# count  500.000000     500.000000      498.000000    499.000000  5.000000e+02
# mean   250.500000   55416.358000        4.538353   3055.203206  2.436323e+05
# std    144.481833   45725.478963       28.549067   5171.981071  4.851937e+05
# min      1.000000   21609.000000      -67.300000 -13038.000000  3.717000e+03
# 25%    125.750000   29003.000000       -5.900000    556.950000  3.658850e+04
# 50%    250.500000   40236.000000        0.550000   1761.600000  7.326150e+04
# 75%    375.250000   63926.750000        6.975000   3954.000000  1.805640e+05
# max    500.000000  485873.000000      442.300000  45687.000000  3.473238e+06
#
#        profit_change  previous_rank  years_on_global_500_list     employees  \
# count     436.000000     500.000000                500.000000  5.000000e+02
# mean       24.152752     222.134000                 15.036000  1.339983e+05
# ...

# %%
f500.describe(include = ["O"])
# Out:
#                                     company                 ceo  \
# count                                   500                 500
# unique                                  500                 500
# top     Guangzhou Automobile Industry Group  Yasuyuki Yoshinaga
# freq                                      1                   1
#
#                              industry      sector country     hq_location  \
# count                             500         500     500             500
# unique                             58          21      34             235
# top     Banks: Commercial and Savings  Financials     USA  Beijing, China
# freq                               51         118     132              56
#
#                                  website
# count                                500
# unique                               500
# top     http://www.marathonpetroleum.com
# freq                                   1

# %%
f500.describe(include = "all")
# Out:
#                                     company        rank       revenues  \
# count                                   500  500.000000     500.000000
# unique                                  500         NaN            NaN
# top     Guangzhou Automobile Industry Group         NaN            NaN
# freq                                      1         NaN            NaN
# mean                                    NaN  250.500000   55416.358000
# std                                     NaN  144.481833   45725.478963
# min                                     NaN    1.000000   21609.000000
# 25%                                     NaN  125.750000   29003.000000
# 50%                                     NaN  250.500000   40236.000000
# 75%                                     NaN  375.250000   63926.750000
# max                                     NaN  500.000000  485873.000000
#
#         revenue_change       profits        assets  profit_change  \
# ...

# %%
f500.head(15)
# Out:
#                      company  rank  revenues  revenue_change  profits  assets  \
# 0                    Walmart     1    485873             0.8  13643.0  198825
# 1                 State Grid     2    315199            -4.4   9571.3  489838
# 2              Sinopec Group     3    267518            -9.1   1257.9  310726
# 3   China National Petroleum     4    262573           -12.3   1867.5  585619
# 4               Toyota Motor     5    254694             7.7  16899.3  437575
# 5                 Volkswagen     6    240264             1.5   5937.3  432116
# 6          Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7         Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                      Apple     9    215639            -7.7  45687.0  321686
# 9                Exxon Mobil    10    205004           -16.7   7840.0  330314
# 10                  McKesson    11    198533             3.1   5070.0   60969
# ...

# %%
f500.tail(10)
# Out:
#                                    company  rank  revenues  revenue_change  \
# 490                          National Grid   491     22036            -3.2
# 491                         Dollar General   492     21987             7.9
# 492                         Telecom Italia   493     21941           -17.4
# 493               Xiamen ITG Holding Group   494     21930            34.3
# 494  Xinjiang Guanghui Industry Investment   495     21919            31.1
# 495         Teva Pharmaceutical Industries   496     21903            11.5
# 496               New China Life Insurance   497     21796           -13.3
# 497              Wm. Morrison Supermarkets   498     21741           -11.3
# 498                                    TUI   499     21655            -5.5
# 499                             AutoNation   500     21609             3.6
#
#      profits  assets  profit_change                 ceo  \
# 490  10150.6   82310          160.2      John Pettigrew
# ...

# %%
f500.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
f500['company']
# Out:
# 0                                           Walmart
# 1                                        State Grid
# 2                                     Sinopec Group
# 3                          China National Petroleum
# 4                                      Toyota Motor
# 5                                        Volkswagen
# 6                                 Royal Dutch Shell
# 7                                Berkshire Hathaway
# 8                                             Apple
# 9                                       Exxon Mobil
# 10                                         McKesson
# 11                                               BP
# 12                               UnitedHealth Group
# 13                                       CVS Health
# 14                              Samsung Electronics
# 15                                         Glencore
# 16                                          Daimler
# 17                                   General Motors
# ...

# %%
f500["company":"revenues"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ea87ef6e35e9> in <module>
# ----> 1 f500["company":"revenues"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2879
#    2880         # Do we have a slicer (on rows)?
# -> 2881         indexer = convert_to_index_sliceable(self, key)
#    2882         if indexer is not None:
#    2883             # either we have a slice or we have a string that can be converted
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2132     idx = obj.index
#    2133     if isinstance(key, slice):
# -> 2134         return idx._convert_slice_indexer(key, kind="getitem")
#    2135
#    2136     elif isinstance(key, str):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
# ...

# %%
f500[['company', 'rank', 'revenues']]

# %% [markdown]
# * iloc : will use when we have integer indexing
# * loc : will use when we have label indexing

# %%
f500[['company', 'rank', 'revenues']][0]

# %%
f500["company"]

# %%
f500.iloc[1:10]

# %%
f500.iloc[:10,0:3]

# %%
f500.iloc[:10,[0,5]]

# %%
f500.iloc[[5,10],[0,5]]

# %%
f500.head()

# %%
f500.loc[3:4]

# %%
f500.loc[3:4,"company":"revenues"]

# %%
f500.head()

# %%
f500 = pd.read_csv("f500.csv", index_col = 0)
f500

# %%
f500.iloc[4,1]

# %%
f500.iloc[4,1] += 10000
f500.iloc[4,1]

# %%
f500["country"]

# %%
country_frq = {}

for c in f500["country"]:
    if c not in country_frq:
        country_frq[c] = 1
    else:
        country_frq[c] += 1

country_frq

# %%
f500["country"].value_counts()

# %%
company_frq = f500["country"].value_counts(normalize = True)*100
company_frq

# %%
(650/1100)*100

# %%
company_frq["India"]

# %%
bl = f500["country"] == "India"

# %%
len(bl)

# %%
f500.shape

# %%
f500[bl]

# %%
data = f500.loc[f500["country"] == "India","ceo":"industry"]
data

# %%
pd.options.display.max_rows = 1000

# %%
data.to_csv("data.csv")
