# %% [markdown]
# <p><img src="https://assets.datacamp.com/production/project_1237/img/netflix.jpg" alt="Someone's feet on table facing a television"></p>
# <p>Netflix! What started in 1997 as a DVD rental service has since exploded into the largest entertainment/media company by <a href="https://www.marketwatch.com/story/netflix-shares-close-up-8-for-yet-another-record-high-2020-07-10">market capitalization</a>, boasting over 200 million subscribers as of <a href="https://www.cbsnews.com/news/netflix-tops-200-million-subscribers-but-faces-growing-challenge-from-disney-plus/">January 2021</a>.</p>
# <p>Given the large number of movies and series available on the platform, it is a perfect opportunity to flex our data manipulation skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. For their first order of business, they have been performing some analyses, and they believe that the average duration of movies has been declining. </p>
# <p>As evidence of this, they have provided us with the following information. For the years from 2011 to 2020, the average movie durations are 103, 101, 99, 100, 100, 95, 95, 96, 93, and 90, respectively.</p>
# <p>If we're going to be working with this data, we know a good place to start would be to probably start working with <code>pandas</code>. But first we'll need to create a DataFrame from scratch. Let's start by creating a Python object covered in <a href="https://learn.datacamp.com/courses/intermediate-python">Intermediate Python</a>: a dictionary!</p>

# %% [markdown]
# ## 1. Creating a DataFrame
# <p>Perfect! We now have our friend's data stored in a nice Python object. We can already perform several operations on a dictionary to manipulate its contents (such as updating or adding to it). But a more useful structure might be a <code>pandas</code> DataFrame, a tabular data structure containing labeled axes and rows. Luckily, DataFrames can be created very easily from the dictionary created in the previous step!</p>
# <p>To convert our dictionary <code>movie_dict</code> to a <code>pandas</code> DataFrame, we will first need to import the library under its usual alias. We'll also want to inspect our DataFrame to ensure it was created correctly. Let's perform these steps now.</p>

# %%
# Import pandas under its usual alias
import pandas as pd
import datetime as dt

# Create a DataFrame from the dictionary
netflix = pd.read_csv("netflix_titles.csv",parse_dates=["release_year"])
pd.options.display.max_rows= 1000

# Print the DataFrame
netflix.head(50)
# Out:
#    show_id     type                                title  \
# 0       s1  TV Show                                   3%
# 1       s2    Movie                                 7:19
# 2       s3    Movie                                23:59
# 3       s4    Movie                                    9
# 4       s5    Movie                                   21
# 5       s6  TV Show                                   46
# 6       s7    Movie                                  122
# 7       s8    Movie                                  187
# 8       s9    Movie                                  706
# 9      s10    Movie                                 1920
# 10     s11    Movie                                 1922
# 11     s12  TV Show                                 1983
# 12     s13  TV Show                                 1994
# 13     s14    Movie                                2,215
# 14     s15    Movie                                 3022
# 15     s16    Movie                               Oct-01
# 16     s17  TV Show                               Feb-09
# 17     s18    Movie                               22-Jul
# 18     s19    Movie                               15-Aug
# 19     s20    Movie                                  '89
# 20     s21    Movie                 ​​Kuch Bheege Alfaaz
# 21     s22    Movie                         ​Goli Soda 2
# 22     s23    Movie                   ​Maj Rati ​​Keteki
# 23     s24    Movie                          ​Mayurakshi
# 24     s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac
# 25     s26    Movie                             (T)ERROR
# 26     s27  TV Show                             (Un)Well
# 27     s28    Movie                               #Alive
# 28     s29    Movie        #AnneFrank - Parallel Stories
# 29     s30  TV Show                             #blackAF
# 30     s31    Movie                     #cats_the_mewvie
# 31     s32    Movie                    #FriendButMarried
# 32     s33    Movie                  #FriendButMarried 2
# 33     s34    Movie                         #realityhigh
# 34     s35    Movie                                #Roxy
# 35     s36    Movie                            #Rucker50
# 36     s37    Movie                              #Selfie
# 37     s38    Movie                           #Selfie 69
# 38     s39  TV Show                  แผนร้ายนายเจ้าเล่ห์
# 39     s40    Movie                       ¡Ay, mi madre!
# 40     s41    Movie                          Çarsi Pazar
# 41     s42    Movie                           Ég man þig
# 42     s43    Movie          Çok Filim Hareketler Bunlar
# 43     s44    Movie                              Òlòtūré
# 44     s45    Movie                             Æon Flux
# 45     s46  TV Show                                Şubat
# 46     s47    Movie                     1 Chance 2 Dance
# 47     s48    Movie                        1 Mile to You
# 48     s49    Movie                  10 Days in Sun City
# 49     s50    Movie                       10 jours en or
#
#                                   director  \
# 0                                      NaN
# 1                        Jorge Michel Grau
# 2                             Gilbert Chan
# 3                              Shane Acker
# 4                           Robert Luketic
# 5                              Serdar Akar
# 6                          Yasir Al Yasiri
# 7                           Kevin Reynolds
# 8                            Shravan Kumar
# 9                             Vikram Bhatt
# 10                            Zak Hilditch
# 11                                     NaN
# 12                    Diego Enrique Osorno
# 13                     Nottapon Boonprakob
# 14                              John Suits
# 15                          Kunle Afolayan
# 16                                     NaN
# 17                         Paul Greengrass
# 18                      Swapnaneel Jayakar
# 19                                     NaN
# 20                                    Onir
# 21                            Vijay Milton
# 22                       Santwana Bardoloi
# 23                             Atanu Ghosh
# 24                                     NaN
# 25  Lyric R. Cabral, David Felix Sutcliffe
# 26                                     NaN
# 27                                  Cho Il
# 28             Sabina Fedeli, Anna Migotto
# 29                                     NaN
# 30                        Michael Margolis
# 31                           Rako Prijanto
# 32                           Rako Prijanto
# 33                        Fernando Lebrija
# 34                         Michael Kennedy
# 35                   Robert McCullough Jr.
# 36                          Cristina Jacob
# 37                          Cristina Jacob
# 38                                     NaN
# 39                             Frank Ariza
# 40                         Muharrem Gülmez
# 41                     Óskar Thór Axelsson
# 42                            Ozan Açıktan
# 43                           Kenneth Gyang
# 44                            Karyn Kusama
# 45                                     NaN
# 46                              Adam Deyoe
# 47                             Leif Tilden
# 48                               Adze Ugah
# 49                       Nicolas Brossette
#
#                                                  cast  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...
# 9   Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...
# 12                                                NaN
# 13                                 Artiwara Kongmalai
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...
# 17  Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# 18  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...
# 19                 Lee Dixon, Ian Wright, Paul Merson
# 20  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...
# 21  Samuthirakani, Bharath Seeni, Vinoth, Esakki B...
# 22  Adil Hussain, Shakil Imtiaz, Mahendra Rabha, S...
# 23  Soumitra Chatterjee, Prasenjit Chatterjee, Ind...
# 24  Bryson Baugus, Emily Neves, Blake Shepard, Pat...
# 25                                                NaN
# 26                                                NaN
# 27                           Yoo Ah-in, Park Shin-hye
# 28                        Helen Mirren, Gengher Gatti
# 29  Kenya Barris, Rashida Jones, Iman Benson, Genn...
# 30                                                NaN
# 31  Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...
# 32  Adipati Dolken, Mawar de Jongh, Sari Nila, Von...
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 34  Jake Short, Sarah Fisher, Booboo Stewart, Dann...
# 35                                                NaN
# 36  Flavia Hojda, Crina Semciuc, Olimpia Melinte, ...
# 37  Maia Morgenstern, Olimpia Melinte, Crina Semci...
# 38  Chutavuth Pattarakampol, Sheranut Yusananda, N...
# 39  Estefanía de los Santos, Secun de la Rosa, Ter...
# 40  Erdem Yener, Ayhan Taş, Emin Olcay, Muharrem G...
# 41  Jóhannes Haukur Jóhannesson, Ágústa Eva Erlend...
# 42  Ayça Erturan, Aydan Taş, Ayşegül Akdemir, Burc...
# 43  Beverly Osu, Sharon Ooja, Omowunmi Dada, Pearl...
# 44  Charlize Theron, Marton Csokas, Jonny Lee Mill...
# 45  Alican Yücesoy, Melisa Sözen, Musa Uzunlar, Se...
# 46  Lexi Giovagnoli, Justin Ray, Rae Latt, Poonam ...
# 47  Billy Crudup, Graham Rogers, Liana Liberato, S...
# 48  Ayo Makun, Adesua Etomi, Richard Mofe-Damijo, ...
# 49  Franck Dubosc, Claude Rich, Marie Kremer, Math...
#
#                            country          date_added release_year rating  \
# 0                           Brazil     August 14, 2020   2020-01-01  TV-MA
# 1                           Mexico   December 23, 2016   2016-01-01  TV-MA
# 2                        Singapore   December 20, 2018   2011-01-01      R
# 3                    United States   November 16, 2017   2009-01-01  PG-13
# 4                    United States     January 1, 2020   2008-01-01  PG-13
# 5                           Turkey        July 1, 2017   2016-01-01  TV-MA
# 6                            Egypt        June 1, 2020   2019-01-01  TV-MA
# 7                    United States    November 1, 2019   1997-01-01      R
# 8                            India       April 1, 2019   2019-01-01  TV-14
# 9                            India   December 15, 2017   2008-01-01  TV-MA
# 10                   United States    October 20, 2017   2017-01-01  TV-MA
# 11           Poland, United States   November 30, 2018   2018-01-01  TV-MA
# 12                          Mexico        May 17, 2019   2019-01-01  TV-MA
# 13                        Thailand       March 1, 2019   2018-01-01  TV-MA
# 14                   United States      March 19, 2020   2019-01-01      R
# 15                         Nigeria   September 1, 2019   2014-01-01  TV-14
# 16                             NaN      March 20, 2019   2018-01-01  TV-14
# 17  Norway, Iceland, United States    October 10, 2018   2018-01-01      R
# 18                           India      March 29, 2019   2019-01-01  TV-14
# 19                  United Kingdom        May 16, 2018   2017-01-01  TV-PG
# 20                           India   September 1, 2018   2018-01-01  TV-14
# 21                           India  September 15, 2018   2018-01-01  TV-14
# 22                           India  September 15, 2018   2017-01-01  TV-14
# 23                           India  September 15, 2018   2017-01-01  TV-14
# 24                           Japan    January 23, 2020   2020-01-01  TV-14
# 25                   United States       June 30, 2016   2015-01-01     NR
# 26                   United States     August 12, 2020   2020-01-01  TV-MA
# 27                     South Korea   September 8, 2020   2020-01-01  TV-MA
# 28                           Italy        July 1, 2020   2019-01-01  TV-14
# 29                   United States      April 17, 2020   2020-01-01  TV-MA
# 30                          Canada    February 5, 2020   2020-01-01  TV-14
# 31                       Indonesia        May 21, 2020   2018-01-01   TV-G
# 32                       Indonesia       June 28, 2020   2020-01-01   TV-G
# 33                   United States   September 8, 2017   2017-01-01  TV-14
# 34                          Canada      April 10, 2019   2018-01-01  TV-14
# 35                   United States    December 1, 2016   2016-01-01  TV-PG
# 36                         Romania        June 1, 2019   2014-01-01  TV-MA
# 37                         Romania        June 1, 2019   2016-01-01  TV-MA
# 38                             NaN      March 30, 2019   2016-01-01  TV-14
# 39                           Spain       July 19, 2019   2019-01-01  TV-MA
# 40                          Turkey      March 10, 2017   2015-01-01  TV-14
# 41                         Iceland      March 27, 2018   2017-01-01  TV-MA
# 42                          Turkey      March 10, 2017   2010-01-01  TV-MA
# 43                         Nigeria     October 2, 2020   2020-01-01  TV-MA
# 44                   United States    February 1, 2018   2005-01-01  PG-13
# 45                          Turkey    January 17, 2017   2013-01-01  TV-MA
# 46                   United States        July 1, 2017   2014-01-01  TV-PG
# 47                   United States        July 7, 2017   2017-01-01  TV-14
# 48           South Africa, Nigeria    October 18, 2019   2017-01-01  TV-14
# 49                          France        July 1, 2017   2012-01-01  TV-14
#
#      duration                                          listed_in  \
# 0   4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1      93 min                       Dramas, International Movies
# 2      78 min                Horror Movies, International Movies
# 3      80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4     123 min                                             Dramas
# 5    1 Season    International TV Shows, TV Dramas, TV Mysteries
# 6      95 min                Horror Movies, International Movies
# 7     119 min                                             Dramas
# 8     118 min                Horror Movies, International Movies
# 9     143 min     Horror Movies, International Movies, Thrillers
# 10    103 min                                  Dramas, Thrillers
# 11   1 Season  Crime TV Shows, International TV Shows, TV Dramas
# 12   1 Season  Crime TV Shows, Docuseries, International TV S...
# 13     89 min  Documentaries, International Movies, Sports Mo...
# 14     91 min    Independent Movies, Sci-Fi & Fantasy, Thrillers
# 15    149 min            Dramas, International Movies, Thrillers
# 16   1 Season                  International TV Shows, TV Dramas
# 17    144 min                                  Dramas, Thrillers
# 18    124 min               Comedies, Dramas, Independent Movies
# 19     87 min                                      Sports Movies
# 20    110 min   Dramas, Independent Movies, International Movies
# 21    128 min   Action & Adventure, Dramas, International Movies
# 22    117 min                       Dramas, International Movies
# 23    100 min                       Dramas, International Movies
# 24  2 Seasons               Anime Series, International TV Shows
# 25     84 min                                      Documentaries
# 26   1 Season                                         Reality TV
# 27     99 min     Horror Movies, International Movies, Thrillers
# 28     95 min                Documentaries, International Movies
# 29   1 Season                                        TV Comedies
# 30     90 min                Documentaries, International Movies
# 31    102 min      Dramas, International Movies, Romantic Movies
# 32    104 min      Dramas, International Movies, Romantic Movies
# 33     99 min                                           Comedies
# 34    105 min                          Comedies, Romantic Movies
# 35     56 min                       Documentaries, Sports Movies
# 36    125 min             Comedies, Dramas, International Movies
# 37    119 min             Comedies, Dramas, International Movies
# 38   1 Season  International TV Shows, Romantic TV Shows, TV ...
# 39     81 min                     Comedies, International Movies
# 40     97 min                     Comedies, International Movies
# 41    106 min                Horror Movies, International Movies
# 42     99 min                     Comedies, International Movies
# 43    107 min                       Dramas, International Movies
# 44     93 min               Action & Adventure, Sci-Fi & Fantasy
# 45   1 Season  Crime TV Shows, International TV Shows, TV Dramas
# 46     89 min                            Dramas, Romantic Movies
# 47    105 min             Dramas, Romantic Movies, Sports Movies
# 48     87 min    Comedies, International Movies, Romantic Movies
# 49     97 min             Comedies, Dramas, International Movies
#
#                                           description
# 0   In a future where the elite inhabit an island ...
# 1   After a devastating earthquake hits Mexico Cit...
# 2   When an army recruit is found dead, his fellow...
# 3   In a postapocalyptic world, rag-doll robots hi...
# 4   A brilliant group of students become card-coun...
# 5   A genetics professor experiments with a treatm...
# 6   After an awful accident, a couple admitted to ...
# 7   After one of his high school students attacks ...
# 8   When a doctor goes missing, his psychiatrist w...
# 9   An architect and his wife move into a castle t...
# 10  A farmer pens a confession admitting to his wi...
# 11  In this dark alt-history thriller, a naïve law...
# 12  Archival video and new interviews examine Mexi...
# 13  This intimate documentary follows rock star Ar...
# 14  Stranded when the Earth is suddenly destroyed ...
# 15  Against the backdrop of Nigeria's looming inde...
# 16  As a psychology professor faces Alzheimer's, h...
# 17  After devastating terror attacks in Norway, a ...
# 18  On India's Independence Day, a zany mishap in ...
# 19  Mixing old footage with interviews, this is th...
# 20  After accidentally connecting over the Interne...
# 21  A taxi driver, a gangster and an athlete strug...
# 22  A successful writer returns to the town that l...
# 23  When a middle-aged divorcee returns to Kolkata...
# 24  Seiya and the Knights of the Zodiac rise again...
# 25  This real-life look at FBI counterterrorism op...
# 26  This docuseries takes a deep dive into the luc...
# 27  As a grisly virus rampages a city, a lone man ...
# 28  Through her diary, Anne Frank's story is retol...
# 29  Kenya Barris and his family navigate relations...
# 30  This pawesome documentary explores how our fel...
# 31  Pining for his high school crush for years, a ...
# 32  As Ayu and Ditto finally transition from best ...
# 33  When nerdy high schooler Dani finally attracts...
# 34  A teenage hacker with a huge nose helps a cool...
# 35  This documentary celebrates the 50th anniversa...
# 36  Two days before their final exams, three teen ...
# 37  After a painful breakup, a trio of party-lovin...
# 38  When two brothers fall for two sisters, they q...
# 39  When her estranged mother suddenly dies, a wom...
# 40  The slacker owner of a public bath house ralli...
# 41  Young urbanites renovating a rundown house, an...
# 42  Vignettes of the summer holidays follow vacati...
# 43  In Lagos, a journalist goes undercover as a pr...
# 44  Aiming to hasten an uprising, the leader of an...
# 45  An orphan subjected to tests that gave him sup...
# 46  When an aspiring dancer is uprooted during her...
# 47  After escaping the bus accident that killed hi...
# 48  After his girlfriend wins the Miss Nigeria pag...
# 49  When a carefree bachelor is unexpectedly left ...

# %%
Netflix = netflix.loc[netflix["duration"].str.endswith("min")].sort(by = "release_year")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8c0b1b2de28c> in <module>
# ----> 1 Netflix = netflix.loc[netflix["duration"].str.endswith("min")].sort(by = "release_year")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
 netflix.loc[netflix["duration"].str.endswith("Season")]

# %%
len(netflix.loc[netflix["duration"].str.endswith("Seasons")])

# %%
5377+1608+802

# %% [markdown]
# ## 2. A visual inspection of our data
# <p>Alright, we now have a <code>pandas</code> DataFrame, the most common way to work with tabular data in Python. Now back to the task at hand. We want to follow up on our friend's assertion that movie lengths have been decreasing over time. A great place to start will be a visualization of the data.</p>
# <p>Given that the data is continuous, a line plot would be a good choice, with the dates represented along the x-axis and the average length in minutes along the y-axis. This will allow us to easily spot any trends in movie durations. There are many ways to visualize data in Python, but <code>matploblib.pyplot</code> is one of the most common packages to do so.</p>
# <p><em>Note: In order for us to correctly test your plot, you will need to initalize a <code>matplotlib.pyplot</code> Figure object, which we have already provided in the cell below. You can continue to create your plot as you have learned in Intermediate Python.</em></p>

# %%
[1,2,3][0]

# %%
Netflix.loc[:,'duration'] = Netflix.loc[:,'duration'].str.replace("min",'').astype(int)

# %%
Netflix["duration"].dtype

# %%
Netflix.head(10)

# %%
# Import matplotlib.pyplot under its usual alias and create a figure
import matplotlib.pyplot as plt
plt.figure(figsize = (8,8))

# Draw a line plot of release_years and durations
plt.plot(Netflix["release_year"].head(4), Netflix["duration"].head(4))
# Create a title
plt.title("Netflix Duration progress",y = 1)
Netflix['duration'].head(12).mean()
# Show the plot
plt.show()

# %% [markdown]
# ## 3. Filtering for movies!
# <p>Okay, we have our data! Now we can dive in and start looking at movie lengths. </p>
# <p>Or can we? Looking at the first five rows of our new DataFrame, we notice a column <code>type</code>. Scanning the column, it's clear there are also TV shows in the dataset! Moreover, the <code>duration</code> column we planned to use seems to represent different values depending on whether the row is a movie or a show (perhaps the number of minutes versus the number of seasons)?</p>
# <p>Fortunately, a DataFrame allows us to filter data quickly, and we can select rows where <code>type</code> is <code>Movie</code>. While we're at it, we don't need information from all of the columns, so let's create a new DataFrame <code>netflix_movies</code> containing only <code>title</code>, <code>country</code>, <code>genre</code>, <code>release_year</code>, and <code>duration</code>.</p>
# <p>Let's put our data subsetting skills to work!</p>

# %%
# Select only the columns of interest
netflix_movies_col_subset = Netflix.loc[Netflix['type'] == "Movie"]

# %%
netflix_movies = netflix_movies_col_subset.loc[:,['title', 'country','release_year',  'duration']]
# Print the first five rows of the new DataFrame
netflix_movies.head(5)

# %% [markdown]
# ## 4. Creating a scatter plot
# <p>Okay, now we're getting somewhere. We've read in the raw data, selected rows of movies, and have limited our DataFrame to our columns of interest. Let's try visualizing the data again to inspect the data over a longer range of time.</p>
# <p>This time, we are no longer working with aggregates but instead with individual movies. A line plot is no longer a good choice for our data, so let's try a scatter plot instead. We will again plot the year of release on the x-axis and the movie duration on the y-axis.</p>
# <p><em>Note: Although not taught in Intermediate Python, we have provided you the code <code>fig = plt.figure(figsize=(12,8))</code> to increase the size of the plot (to help you see the results), as well as to assist with testing. For more information on how to create or work with a <code>matplotlib</code> <code>figure</code>, refer to the <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html">documentation</a>.</em></p>

# %%
# Create a figure and increase the figure size
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus year
...

# Create a title
...

# Show the plot
...

# %% [markdown]
# ## 5. Digging deeper
# <p>This is already much more informative than the simple plot we created when our friend first gave us some data. We can also see that, while newer movies are overrepresented on the platform, many short movies have been released in the past two decades.</p>
# <p>Upon further inspection, something else is going on. Some of these films are under an hour long! Let's filter our DataFrame for movies with a <code>duration</code> under 60 minutes and look at the genres. This might give us some insight into what is dragging down the average.</p>

# %%
# Filter for durations shorter than 60 minutes
short_movies = ...

# Print the first 20 rows of short_movies
...

# %% [markdown]
# ## 6. Marking non-feature films
# <p>Interesting! It looks as though many of the films that are under 60 minutes fall into genres such as "Children", "Stand-Up", and "Documentaries". This is a logical result, as these types of films are probably often shorter than 90 minute Hollywood blockbuster. </p>
# <p>We could eliminate these rows from our DataFrame and plot the values again. But another interesting way to explore the effect of these genres on our data would be to plot them, but mark them with a different color.</p>
# <p>In Python, there are many ways to do this, but one fun way might be to use a loop to generate a list of colors based on the contents of the <code>genre</code> column. Much as we did in Intermediate Python, we can then pass this list to our plotting function in a later step to color all non-typical genres in a different color!</p>
# <p><em>Note: Although we are using the basic colors of red, blue, green, and black, <code>matplotlib</code> has many named colors you can use when creating plots. For more information, you can refer to the documentation <a href="https://matplotlib.org/stable/gallery/color/named_colors.html">here</a>!</em></p>

# %%
# Define an empty list
colors = ...

# Iterate over rows of netflix_movies_col_subset
for ..., ... in ... :
    if ... :
        ...
    elif ... :
        ...
    elif ... :
        ...
    else:
        ...
        
# Inspect the first 10 values in your list        
...

# %% [markdown]
# ## 7. Plotting with color!
# <p>Lovely looping! We now have a <code>colors</code> list that we can pass to our scatter plot, which should allow us to visually inspect whether these genres might be responsible for the decline in the average duration of movies.</p>
# <p>This time, we'll also spruce up our plot with some additional axis labels and a new theme with <code>plt.style.use()</code>. The latter isn't taught in Intermediate Python, but can be a fun way to add some visual flair to a basic <code>matplotlib</code> plot. You can find more information on customizing the style of your plot <a href="https://matplotlib.org/stable/tutorials/introductory/customizing.html">here</a>!</p>

# %%
# Set the figure style and initalize a new figure
plt.style.context('dark_background')
fig = plt.figure(figsize=(12,8))
plt.plot(Netflix['release_year'].head(3) ,Netflix['duration'].head(3))
# Create a scatter plot of duration versus release_year
...

# Create a title and axis labels
...
...
...

# Show the plot
plt.show()

# %% [markdown]
# # 8. Are we certain that movies are getting shorter?

# %%
257 is 257
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-3-dd70d8dec340>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   257 is 257
# True
