# %%
import pandas as pd
pd.options.display.max_rows = 20000

# %%
android  = pd.read_csv("googleplaystore.csv")

# %%
android
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
android.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
android.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
android.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
android["Category"].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
check = android["Category"] == '1.9'

# %%
android[check]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
android.iloc[10472,1]
# Out:
# '1.9'

# %%
android.iloc[10472,1] = "LIFESTYLE"
android.iloc[10472,2] = "1.9"
android.iloc[10472,3] = 19.0
android.iloc[10472,4] = "3.0M"
android.iloc[10472,5] = "1,000+"
android.iloc[10472,6] = "Free"
android.iloc[10472,-1] = "4.0 and up"
android.iloc[10472,-2] = "1.0.19"
android.iloc[10472,-3] = "February 11, 2018"
android.iloc[10472,-4] = "Lifestyle"
android.iloc[10472,-5] = "Everyone"
android.iloc[10472,-6] = "0" #['Life Made WI-Fi Touchscreen Photo Frame', 'LIFESTYLE', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'February 11, 2018', '1.0.19', '4.0 and up']

# %%
list(android.iloc[10472])
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame',
#  'LIFESTYLE',
#  '1.9',
#  19.0,
#  '3.0M',
#  '1,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'Lifestyle',
#  'February 11, 2018',
#  '1.0.19',
#  '4.0 and up']

# %%
android.iloc[10472,-4]
# Out:
# 'Lifestyle'

# %%
android["App"].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
check = android['App'] == "Instagram"

# %%
android[['Reviews']] = android[['Reviews']].apply(pd.to_numeric )

# %%
android[['Reviews']].idxmax() # Ab smjy Huzaifa
android.loc[check,"Reviews"].idxmax()
# Out:
# 2604

# %%
App_names = set(android['App'])

# %%
App_idx = {}
for i in App_names:
    check = android["App"] == i
    App_idx[i] = android.loc[check,"Reviews"].idxmax()

# %%
App_idx
# Out:
# {'あなカレ【BL】無料ゲーム': 6418,
#  'CN Summer Challenge': 7583,
#  'Dr. Panda Restaurant 3': 2068,
#  'Alt-C': 4008,
#  'StyleSeat': 1606,
#  'Citymapper - Transit Navigation': 8357,
#  'Tennis Champion 3D - Online Sports Game': 5420,
#  'BN Pro RobotoXL-b HD Text': 6515,
#  'Real Madrid App': 9564,
#  'Ay Hasnain k Nana Milad Naat': 5842,
#  'DZ Register': 9139,
#  'ipsy: Makeup, Beauty, and Tips': 99,
#  'Millionaire : Who want to be?': 6050,
#  'Call of Mini™ Zombies 2': 7660,
#  'CE SmartApp.com': 7199,
#  "Oddworld: New 'n' Tasty": 4419,
#  'Allrecipes Dinner Spinner': 1226,
#  '[BN] Blitz': 6513,
#  'Magnum 3.0 Gun Custom SImulator': 10673,
#  'My Style CM 13 Theme': 7571,
#  'Lesbian Chat & Dating - SPICY': 6285,
#  'HD VideoDownlaoder For Fb : XXVideo Downloader': 10237,
#  'Emo Ads Blocker Browser': 4981,
#  'Z Day: Hearts of Heroes': 4819,
#  'Strawberry Shortcake Ice Cream Island': 9936,
#  'Wi-Fi Auto-connect': 10445,
#  "Connect'Em": 9581,
# ...

# %%
App_idx["ZOOM Cloud Meetings"]
# Out:
# 213

# %%
android.loc[check,:]
# Out:
#           App          Category Rating  Reviews Size Installs  Type Price  \
# 9013  DW Maps  TRAVEL_AND_LOCAL    3.7     35.0  13M  10,000+  Free     0
#
#      Content Rating          Genres  Last Updated Current Ver   Android Ver
# 9013       Everyone  Travel & Local  June 6, 2017         1.9  2.3.3 and up

# %%
a = dict(android.iloc[213,:])
print(a)
# Out:
# {'App': 'ZOOM Cloud Meetings', 'Category': 'BUSINESS', 'Rating': 4.4, 'Reviews': 31614.0, 'Size': '37M', 'Installs': '10,000,000+', 'Type': 'Free', 'Price': '0', 'Content Rating': 'Everyone', 'Genres': 'Business', 'Last Updated': 'July 20, 2018', 'Current Ver': '4.1.28165.0716', 'Android Ver': '4.0 and up'}

# %%
data = pd.DataFrame()

# %%
len(App_idx)
# Out:
# 9660

# %%
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in App_idx:
    data = data.append(dict(android.iloc[App_idx[i],:]), ignore_index=True)

# %%
data.head(5)
# Out:
#     Android Ver                     App      Category Content Rating  \
# 0    2.3 and up           あなカレ【BL】無料ゲーム        FAMILY     Mature 17+
# 1    4.4 and up     CN Summer Challenge        FAMILY       Everyone
# 2    4.1 and up  Dr. Panda Restaurant 3        FAMILY       Everyone
# 3    4.0 and up                   Alt-C  PRODUCTIVITY       Everyone
# 4  4.0.3 and up               StyleSeat     LIFESTYLE       Everyone
#
#   Current Ver                     Genres    Installs       Last Updated Price  \
# 0       4.2.2                 Simulation    100,000+  February 25, 2018     0
# 1         1.1  Entertainment;Brain Games    100,000+       May 24, 2018     0
# 2       1.6.4   Educational;Pretend Play  1,000,000+     March 23, 2018     0
# 3        1.37               Productivity     10,000+   January 27, 2017     0
# 4        4.35                  Lifestyle    500,000+      July 31, 2018     0
#
#   Rating  Reviews  Size  Type
# 0    4.7   6073.0  8.5M  Free
# ...

# %%
data.shape
# Out:
# (9660, 13)

# %%
data.loc[:,'App']
# Out:
# 0                        あなカレ【BL】無料ゲーム
# 1                  CN Summer Challenge
# 2               Dr. Panda Restaurant 3
# 3                                Alt-C
# 4                            StyleSeat
#                      ...
# 9655          SW Battlefront Companion
# 9656          PlacarTv Futebol Ao Vivo
# 9657     Upgrade for Android DU Master
# 9658    MSN Money- Stock Quotes & News
# 9659                           DW Maps
# Name: App, Length: 9660, dtype: object

# %%
# def is_English(app_name):
#     lst = []
#     for i in app_name:
#         if ord(i) <= 127:
#             lst.append(True)
#         else:
#             lst.append(False)
#     return True if lst.count(False) <= 3 else False

# %%
is_English = lambda x:[ True if ord(i)<=127 else False for i in x ].count(False) <= 3

# %%
ord('®')
# Out:
# 174

# %%
check = data.loc[:,"App"].apply(is_English)

# %%
check
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9655     True
# 9656     True
# 9657     True
# 9658     True
# 9659     True
# Name: App, Length: 9660, dtype: bool

# %%
len(data.loc[check,:])
# Out:
# 9615

# %%
American_Apps = data.loc[check,:]

# %%
American_Apps.head(5)
# Out:
#           Android Ver                              App             Category  \
# 1          4.4 and up              CN Summer Challenge               FAMILY
# 2          4.1 and up           Dr. Panda Restaurant 3               FAMILY
# 3          4.0 and up                            Alt-C         PRODUCTIVITY
# 4        4.0.3 and up                        StyleSeat            LIFESTYLE
# 5  Varies with device  Citymapper - Transit Navigation  MAPS_AND_NAVIGATION
#
#   Content Rating         Current Ver                     Genres    Installs  \
# 1       Everyone                 1.1  Entertainment;Brain Games    100,000+
# 2       Everyone               1.6.4   Educational;Pretend Play  1,000,000+
# 3       Everyone                1.37               Productivity     10,000+
# 4       Everyone                4.35                  Lifestyle    500,000+
# 5       Everyone  Varies with device          Maps & Navigation  5,000,000+
#
# ...

# %%
check = American_Apps['Type'] == "Free"

# %%
android_final = American_Apps.loc[check,:]

# %%
len(android_final)
# Out:
# 8864
